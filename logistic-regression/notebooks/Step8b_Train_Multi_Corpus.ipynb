# %% [markdown]
# # Step 8b — Multi-corpus classifier training
#
# Thin wrapper: edits go in `step8b_train_multi_corpus.py`, sync to Drive, re-run cells. `importlib.reload` picks up changes without restarting kernel.
#
# Outputs `results.json` + per-config pickles to `outputs/models_multi/`.

# %%
# 1. Mount Drive + PROJECT_ROOT

import os, sys
try:
    from google.colab import drive
    drive.mount('/content/drive')
    PROJECT_ROOT = '/content/drive/MyDrive/text-difficulty-classification'
except Exception:
    PROJECT_ROOT = os.path.abspath('.')
os.environ['PROJECT_ROOT'] = PROJECT_ROOT
if PROJECT_ROOT not in sys.path:
    sys.path.insert(0, PROJECT_ROOT)
print('PROJECT_ROOT =', PROJECT_ROOT)
for p in ['outputs/features_multi', 'outputs/models_multi']:
    os.makedirs(os.path.join(PROJECT_ROOT, p), exist_ok=True)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# PROJECT_ROOT = /content/drive/MyDrive/text-difficulty-classification

# %%
# 2. Import + reload the .py module (auto-picks up edits)
import importlib
import step8h_better_classifiers as step8h
importlib.reload(step8h)
print('loaded:', step8h.__file__)
# Out:
# loaded: /content/drive/MyDrive/text-difficulty-classification/step8h_better_classifiers.py

# %%
sys.argv = ['step8h']
step8h.main()
# Out:
# [step8h] feature_sets=['prompts_qwen2.5-7b'] classifiers=['xgb', 'lgbm', 'mlp', 'mlp_corn']
# [step8h] prompts_qwen2.5-7b         xgb        val=0.704 test=0.701 qwk=0.716 ood=['onestop=0.26', 'openbookqa=0.21', 'race-high=0.26', 'race-middle=0.17']  (2.4s)
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# ...
